# %%
# python env: modnenv_v2

import os
import string
import random
import numpy as np
from sklearn.model_selection import KFold
from pathlib import Path, PosixPath
import matplotlib.pyplot as plt
import json 
import pandas as pd
from copy import deepcopy
from modnet.models import EnsembleMODNetModel
from modnet.preprocessing import MODData
from modnet.hyper_opt import FitGenetic
from monty.serialization import dumpfn, loadfn, MontyDecoder
from optimade.adapters import Structure as optim_Structure
from pymatgen.ext.matproj import MPRester
from pymatgen.core.structure import Structure
from pymongo import MongoClient
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error, mean_squared_error 
from scipy.stats import spearmanr
from IPython.display import Image
from tqdm import tqdm
from os import listdir
from os.path import isfile, join
import pickle
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# 2024-02-05 15:36:31.610644: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-05 15:36:31.633816: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-05 15:36:31.748267: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-05 15:36:31.748375: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-05 15:36:31.767645: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-05 15:36:31.807037: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-05 15:36:31.807755: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-05 15:36:32.760816: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
client = MongoClient('emma.pcpm.ucl.ac.be', 27017, username='structDB', password='structDB2018', authSource='structure_databases', authMechanism='SCRAM-SHA-1')
db = client.structure_databases


collection = db.full_unique

collections_chemenv = {"csd": db.csd_chemenv,
                       "cod": db.cod_chemenv,
                       "icsd": db.icsd_chemenv,
                       "pauling": db.pauling_chemenv}

collections_unique = {"csd": db.csd_unique,
                       "cod": db.cod_unique,
                       "icsd": db.icsd_unique,
                       "pauling": db.pauling_unique}

collections_raw = {"csd": db.csd_unique,
                   "cod": db.cod_unique,
                   "icsd": db.icsd_unique,
                   "pauling": db.pauling_unique}

# %%
# Example
r = collection.find_one({"mp_ids": "mp-149"})

print(r["formula_pretty"], r["formula_anonymous"])
print(r["source"], r["source_id"])


chemenv = collections_chemenv[r["source"]].find_one({"unique_id": r["source_id"]})
print(chemenv)


data = collections_unique[r["source"]].find_one({"unique_id": r["source_id"]})

structure = Structure.from_dict(data["structure"])
print(structure)


# for r in collection.find({"elements":{"$in": ["Si", "O"]}, "nelements": 2}):
#     print(r["formula_pretty"])

# print(collection.count({"is_ordered": True}))
# Out:
# Si A
# cod 4104917
# {'_id': ObjectId('5aea4c575a390f5b556fc6e0'), '@module': 'pymatgen.analysis.chemenv.coordination_environments.structure_environments', '@class': 'LightStructureEnvironments', 'strategy': {'@module': 'pymatgen.analysis.chemenv.coordination_environments.chemenv_strategies', '@class': 'MultiWeightsChemenvStrategy', 'additional_condition': 1, 'symmetry_measure_type': 'csm_wcs_ctwcc', 'dist_ang_area_weight': {'@module': 'pymatgen.analysis.chemenv.coordination_environments.chemenv_strategies', '@class': 'DistanceAngleAreaNbSetWeight', 'weight_type': 'has_intersection', 'surface_definition': {'type': 'standard_elliptic', 'distance_bounds': {'lower': 1.15, 'upper': 2.0}, 'angle_bounds': {'lower': 0.05, 'upper': 0.75}}, 'nb_sets_from_hints': 'fallback_to_source', 'other_nb_sets': '0_weight', 'additional_condition': 1}, 'self_csm_weight': {'@module': 'pymatgen.analysis.chemenv.coordination_environments.chemenv_strategies', '@class': 'SelfCSMNbSetWeight', 'effective_csm_estimator': {'function': 'power2_inverse_decreasing', 'options': {'max_csm': 8.0}}, 'weight_estimator': {'function': 'power2_decreasing_exp', 'options': {'max_csm': 8.0, 'alpha': 1.0}}, 'symmetry_measure_type': 'csm_wcs_ctwcc'}, 'delta_csm_weight': {'@module': 'pymatgen.analysis.chemenv.coordination_environments.chemenv_strategies', '@class': 'DeltaCSMNbSetWeight', 'effective_csm_estimator': {'function': 'power2_inverse_decreasing', 'options': {'max_csm': 8.0}}, 'weight_estimator': {'function': 'smootherstep', 'options': {'delta_csm_min': 3.25, 'delta_csm_max': 8.0}}, 'delta_cn_weight_estimators': {'1': {'function': 'smootherstep', 'options': {'delta_csm_min': 0.5, 'delta_csm_max': 5.25}}, '2': {'function': 'smootherstep', 'options': {'delta_csm_min': 0.75, 'delta_csm_max': 5.5}}, '3': {'function': 'smootherstep', 'options': {'delta_csm_min': 1.0, 'delta_csm_max': 5.75}}, '4': {'function': 'smootherstep', 'options': {'delta_csm_min': 1.25, 'delta_csm_max': 6.0}}, '5': {'function': 'smootherstep', 'options': {'delta_csm_min': 1.5, 'delta_csm_max': 6.25}}, '6': {'function': 'smootherstep', 'options': {'delta_csm_min': 1.75, 'delta_csm_max': 6.5}}, '7': {'function': 'smootherstep', 'options': {'delta_csm_min': 2.0, 'delta_csm_max': 6.75}}, '8': {'function': 'smootherstep', 'options': {'delta_csm_min': 2.25, 'delta_csm_max': 7.0}}, '9': {'function': 'smootherstep', 'options': {'delta_csm_min': 2.5, 'delta_csm_max': 7.25}}, '10': {'function': 'smootherstep', 'options': {'delta_csm_min': 2.75, 'delta_csm_max': 7.5}}, '11': {'function': 'smootherstep', 'options': {'delta_csm_min': 3.0, 'delta_csm_max': 7.75}}, '12': {'function': 'smootherstep', 'options': {'delta_csm_min': 3.25, 'delta_csm_max': 8.0}}}, 'symmetry_measure_type': 'csm_wcs_ctwcc'}, 'cn_bias_weight': None, 'angle_weight': None, 'normalized_angle_distance_weight': None, 'ce_estimator': {'function': 'power2_inverse_power2_decreasing', 'options': {'max_csm': 8.0}}}, 'structure': {'@module': 'pymatgen.core.structure', '@class': 'Structure', 'charge': None, 'lattice': {'matrix': [[5.43088, 0.0, 3.325454904276689e-16], [8.733521135675853e-16, 5.43088, 3.325454904276689e-16], [0.0, 0.0, 5.43088]], 'a': 5.43088, 'b': 5.43088, 'c': 5.43088, 'alpha': 90.0, 'beta': 90.0, 'gamma': 90.0, 'volume': 160.1808597516575}, 'sites': [{'species': [{'element': 'Si', 'occu': 1.0}], 'abc': [0.125, 0.125, 0.125], 'xyz': [0.6788600000000001, 0.67886, 0.6788600000000001], 'label': 'Si'}, {'species': [{'element': 'Si', 'occu': 1.0}], 'abc': [0.375, 0.375, 0.875], 'xyz': [2.0365800000000003, 2.03658, 4.752020000000001], 'label': 'Si'}, {'species': [{'element': 'Si', 'occu': 1.0}], 'abc': [0.875, 0.375, 0.375], 'xyz': [4.75202, 2.03658, 2.0365800000000003], 'label': 'Si'}, {'species': [{'element': 'Si', 'occu': 1.0}], 'abc': [0.375, 0.875, 0.375], 'xyz': [2.0365800000000007, 4.75202, 2.0365800000000003], 'label': 'Si'}, {'species': [{'element': 'Si', 'occu': 1.0}], 'abc': [0.125, 0.625, 0.625], 'xyz': [0.6788600000000006, 3.3943000000000003, 3.3 ...
# Full Formula (Si8)
# Reduced Formula: Si
# abc   :   5.430880   5.430880   5.430880
# angles:  90.000000  90.000000  90.000000
# pbc   :       True       True       True
# Sites (8)
#   #  SP        a      b      c
# ---  ----  -----  -----  -----
#   0  Si    0.125  0.125  0.125
#   1  Si    0.375  0.375  0.875
#   2  Si    0.875  0.375  0.375
#   3  Si    0.375  0.875  0.375
#   4  Si    0.125  0.625  0.625
#   5  Si    0.625  0.125  0.625
#   6  Si    0.625  0.625  0.125
#   7  Si    0.875  0.875  0.875

# %%
structures_mshp = []

path_lst_mshp_struc = Path('lst_mshp_struc.pkl')

if path_lst_mshp_struc.exists():
    with open(path_lst_mshp_struc, 'rb') as f:
        structures_mshp = pickle.load(f)
else:
    for r in tqdm(collection.find()):
        data = collections_unique[r["source"]].find_one({"unique_id": r["source_id"]})

        structures_mshp.append(Structure.from_dict(data["structure"]))
    with open(path_lst_mshp_struc, 'wb') as f:
        pickle.dump(structures_mshp, f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 10
#       8 else:
#       9     for r in collection.find():
# ---> 10         data = collections_unique[r["source"]].find_one({"unique_id": r["source_id"]})
#      12         structures_mshp.append(Structure.from_dict(data["structure"]))
#      13     with open(path_lst_mshp_struc, 'wb') as f:
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/collection.py:1506, in Collection.find_one(self, filter, *args, **kwargs)
#    1504     filter = {"_id": filter}
#    1505 cursor = self.find(filter, *args, **kwargs)
# -> 1506 for result in cursor.limit(-1):
#    1507     return result
#    1508 return None
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/mongo_client.py:1453, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
# -> 1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
#    1462     ).run()
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/mongo_client.py:2445, in _ClientConnectionRetryable._read(self)
#    2443 if self._retrying and not self._retryable:
#    2444     self._check_last_error()
# -> 2445 return self._func(self._session, self._server, conn, read_pref)
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/server.py:148, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     146 else:
#     147     conn.send_message(data, max_doc_size)
# --> 148     reply = conn.receive_message(request_id)
#     150 # Unpack and check for command errors.
#     151 if use_cmd:
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/pool.py:1020, in Connection.receive_message(self, request_id)
#    1015 """Receive a raw BSON message or raise ConnectionFailure.
#    1016
#    1017 If any exception is raised, the socket is closed.
#    1018 """
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#    1022     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File ~/anaconda3/envs/modnenv_v2_jf/lib/python3.9/site-packages/pymongo/network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# KeyboardInterrupt:
